# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from PIL import Image
import sys
#sys.path.append('/Users/arthurbabey/Documents/master2/ML/road66/scripts')
sys.path.append('C:/Users/joeld/Desktop/EPFL/machine learning/road66/scripts')
from helpers import *
import lightgbm as lgb
import skimage as skimg

# %%
# Loaded a set of images
root_dir = "../Datasets/training/"

image_dir = root_dir + "images/"
files = os.listdir(image_dir)
n = len(files) # Use all images
print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + files[i]) for i in range(n)]
print(files[0])

gt_dir = root_dir + "groundtruth/"
print("Loading " + str(n) + " images")
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]
print(files[0])
# Out:
# Loading 100 images
# satImage_001.png
# Loading 100 images
# satImage_001.png

# %%
fig1 = plt.figure(figsize=(10, 10)) # create a figure with the default size 
plt.imshow(imgs[1])
imgs[1].shape
# Out:
# (400, 400, 3)

# %%
rotimg = skimg.transform.rotate(imgs[1], 45, resize=False, mode='reflect')
rotgtimg = skimg.transform.rotate(gt_imgs[1], 45, resize=False, mode='reflect')

# %%
fig1 = plt.figure(figsize=(10, 10))
plt.imshow(rotimg)
fig2 = plt.figure(figsize=(10, 10))
plt.imshow(rotgtimg)
rotimg.shape
# Out:
# (400, 400, 3)

# %%
X,Y = rotate_images(imgs, gt_imgs, [45])

# %%
fig1 = plt.figure(figsize=(10, 10))
plt.imshow(X[99])

# %%
fig1 = plt.figure(figsize=(10, 10))
plt.imshow(X[199])
